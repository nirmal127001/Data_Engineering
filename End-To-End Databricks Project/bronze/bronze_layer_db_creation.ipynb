# %%
spark.sql("create database if not exists global_retail_bronze")
# Out:
# Out[1]: DataFrame[]

# %%
spark.sql("show databases").show()
# Out:
# +--------------------+
# |        databaseName|
# +--------------------+
# |             default|
# |global_retail_bronze|
# +--------------------+

# %%
spark.sql("use global_retail_bronze")
# Out:
# Out[3]: DataFrame[]

# %%
# %sql
select current_database()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_database()</th></tr></thead><tbody><tr><td>global_retail_bronze</td></tr></tbody></table></div>

# %%
# dbutils.fs.cp("dbfs:/FileStore/GlobalRetail/notebooks/customer.csv","dbfs:/FileStore/GlobalRetail/bronze_layer/customer_data/customer.csv")
# dbutils.fs.cp("dbfs:/FileStore/GlobalRetail/notebooks/products.json","dbfs:/FileStore/GlobalRetail/bronze_layer/product_catalog/products.json")
# dbutils.fs.cp("dbfs:/FileStore/GlobalRetail/notebooks/transaction_snappy.parquet","dbfs:/FileStore/GlobalRetail/bronze_layer/transaction/transaction_snappy.parquet")
